# %%
import pandas as pd

df = pd.read_csv("hf://datasets/Owishiboo/grammar-correction/dataset3.csv")

# %%
df
# Out:
#       Unnamed: 0                                              input  \
# 0              0   New and new technology has been introduced to...
# 1              1   New and new technology has been introduced to...
# 2              2   New and new technology has been introduced to...
# 3              3   New and new technology has been introduced to...
# 4              4   One possible outcome is that an environmental...
# ...          ...                                                ...
# 5999        5999           Sceene of violence can affect on them .
# 6000        6000   While the communities in general have reckone...
# 6001        6001   While the communities in general have reckone...
# 6002        6002   While the communities in general have reckone...
# 6003        6003   While the communities in general have reckone...
#
#                                                  target
# 0       New technology has been introduced to society .
# ...

# %%
df.drop(['Unnamed: 0'], axis =1 , inplace = True)

# %%
df.duplicated().sum()
# Out:
# 1125

# %%
df
# Out:
#                                                   input  \
# 0      New and new technology has been introduced to...
# 1      New and new technology has been introduced to...
# 2      New and new technology has been introduced to...
# 3      New and new technology has been introduced to...
# 4      One possible outcome is that an environmental...
# ...                                                 ...
# 5999           Sceene of violence can affect on them .
# 6000   While the communities in general have reckone...
# 6001   While the communities in general have reckone...
# 6002   While the communities in general have reckone...
# 6003   While the communities in general have reckone...
#
#                                                  target
# 0       New technology has been introduced to society .
# 1     New technology has been introduced into the so...
# 2     Newer and newer technology has been introduced...
# 3     Newer and newer technology has been introduced...
# ...
